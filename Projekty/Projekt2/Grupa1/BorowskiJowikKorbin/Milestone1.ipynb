# %% [markdown]
# # <center>Eksploracja zbioru danych `Asian Religions Data` </center>

# %%
# Pakiety
import pandas as pd
import numpy as np
import sklearn
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from scipy import stats
from collections import Counter 
import matplotlib.pyplot as plt
import re
plt.rcParams["figure.figsize"] = (20,10)
# Ustawienie ziarna, pozwala zachować reprodukowalność wyników
np.random.seed(123)

# %%
# Wczytanie danych
data = pd.read_csv("./AsianReligionsData/AllBooks_baseline_DTM_Labelled.csv")
data.rename(columns={'Unnamed: 0':'Text'}, inplace=True)

# %% [markdown]
# Większość tekstów w tym zbiorze danych zebrano z projektu Gutenberg. W zbiorze uwzględnioro się 8 ksiąg religijnych, w badaniu rozważono 8265 słów.

# %%
# Sprawdzenie wymiarów zbioru oraz obecnych w nim typów danych.
print('\033[1m' + 'Asian Religions Data:' + '\033[0m')
data.info()
# Out:
# Asian Religions Data:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 590 entries, 0 to 589
# Columns: 8267 entries, Text to explains
# dtypes: int64(8266), object(1)
# memory usage: 37.2+ MB

# %% [markdown]
# Poza pierwszym artybutem, tożsamym z nazwą/rozdziałem księgi, wszystkie zmienne objaśniające mają charakter liczbowy.

# %%
# Sprawdzenie zbioru pod kątem obecności braków danych.
data.isnull().values.any()
# Out:
# False

# %% [markdown]
# W zbiorze nie występują braki danych. Dane nie wymagają czyszczenia.

# %%
def scaller(df):
    # Skalowanie danych numerycznych
    num = df.select_dtypes(include=['float64', 'int64']).columns
    df2 = df.copy()
    scaler = StandardScaler()
    df2[num] = scaler.fit_transform(df2[num])
    return(df2)

# %%
def correlated_pairs(df):
    df2 = scaller(df)
    # Bezwzględne korelacje zmiennych
    corr=df2.iloc[:, 1:].corr().abs()
    # Z powodu symetrii macierzy wybieramy podmacierz trójkątną górną bez diagonali
    upper = corr.where(np.triu(np.ones(corr.shape), k=1).astype(np.bool))
    triu = upper.unstack().sort_values(ascending=False)
    # Wybór najsilniej skorelowanych par zmiennych
    result = triu[triu >= 0.8]
    return result

result = correlated_pairs(data)

# %%
result
# Out:
# breathes      neitherpainfulnorpleasant    1.000000
# smoulder      blaze                        1.000000
# extend        thoroughbreds                1.000000
# establisheth  resisteth                    1.000000
# secondly      colt                         1.000000
#                                              ...
# extent        disposed                     0.800131
#               apprentice                   0.800131
# apprentice    tendons                      0.800131
# mindful       culmination                  0.800095
# internal      winds                        0.800008
# Length: 35328, dtype: float64

# %%
result.describe()
# Out:
# count    35328.000000
# mean         0.966030
# std          0.061034
# min          0.800008
# 25%          0.948630
# 50%          1.000000
# 75%          1.000000
# max          1.000000
# dtype: float64

# %% [markdown]
# Niektóre pary wyrazów są bardzo silnie skorelowane.

# %%
# Przekształcenie kolumn na wektory
# Funkcja przyjmuje na wejściu ramkę danych,
# na wyjściu zwraca słownik o strukturze: klucz - słowo, wartość - wektor
def to_embedding_dict(data):
    data1 = scaller(data)
    # Tworzenie słownika
    embeddings_dict = {}
    for col in data1.columns:
        if col == data1.columns[0]:
            continue
        word = col.lower()
        vector = np.asarray(data1.loc[:, [col]])
        embeddings_dict[word] = vector
    return(embeddings_dict)

# %%
embedding_dict = to_embedding_dict(data)

# %%
# Funkcja znajdująca tablicę najbliższych sąsiadów (kluczy) najbliższych sąsiadów klucza 
# podanego na wejściu. Czyli w efekcie słów, które występują równie często, co słowo
# podane na wejściu. Pozwala też sprawdzić czy dane słowo w ogóle występuje w słowniku.
def nearest_neigh(key):
    # Sprawdzenie czy w słowniku znajduje się wprowadzony klucz
    if not key in list(embedding_dict.keys()):
        return None
    # Zmienne pomocnicze
    min_dist = float('inf')
    nearest = []
    # Szukanie najbliższego klucza
    for k in list(embedding_dict.keys()):
        if k == key:
            continue
        dist = np.linalg.norm(embedding_dict.get(k)-embedding_dict.get(key))
        if dist < min_dist:
            min_dist = dist
            nearest = []
            nearest.append(k)
        # Przypadek gdy mamy kilka "równoodległych" kluczy
        elif dist == min_dist:
            nearest.append(k)
    return nearest

# %%
# Sprawdzenie rzeczowników wymienionych wśród najczęściej występujących w Biblii
print(nearest_neigh('lord'))
print(nearest_neigh('god'))
print(nearest_neigh('mercy'))
print(nearest_neigh('jesus'))
print(nearest_neigh('faith'))
print(nearest_neigh('evil'))
print(nearest_neigh('spirit'))
# Out:
# ['fear']
# ['hath']
# ['riotous', 'perfections', 'praying', 'borrowing', 'tempteth', 'repaying', 'assuage', 'pebble', 'concertation']
# ['bibles', 'bethhoron', 'protested', 'beset', 'caleb', 'josue', 'lords', 'floweth', 'jos', 'samuel', 'jephone', 'successor', 'withholding', 'shoe', 'tyrians', 'thundered', 'appeasing', 'stopped', 'resisted', 'assaulted']
# ['dispensed', 'dealeth', 'scarcely', 'replenisheth', 'charge', 'concert', 'emerald', 'elder', 'acquitted', 'valour', 'carbuncle']
# ['good']
# ['dieth']

# %%
# Najczęściej występujące w ramce słowa 
def most_frequent_words(data,n=10):
    words = data.columns
    words = np.delete(words,0)
    words_counter = np.array([0]*8266)
    for i in range(len(data.iloc[:,1])):
        row = np.array(data.iloc[i,:])

        row = np.delete(row,0)
        words_counter= words_counter+row 
    out = dict(zip(words,words_counter))
    out = Counter(out)
    return dict(out.most_common(n))

# %%
most = most_frequent_words(data,n =15 )


fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
langs = list(most.values())
students = most.keys()
ax.tick_params(axis='both', which='major', labelsize=20)
ax.bar(students,langs)
plt.show()

# %% [markdown]
# Nie wchodząc na razie w szczegóły warto zauważyć że nie pojawiły się słowa takie jak 'and' albo 'is' co może świadczyć o ich braku. Zbiór prawdopodobnie został wyczyszczony (choć nie koniecznie).

# %%
# Sprawdźmy czy faktycznie w zbiorze nie ma słow 'and' i 'is'
print(nearest_neigh('and'))
print(nearest_neigh('is'))
print(nearest_neigh('of'))
print(nearest_neigh('to'))
# Out:
# None
# None
# None
# None

# %% [markdown]
# Ramka danych jest pozbawiona typowych angielskich wyrazów. Choć nie wszystkich:

# %%
print(nearest_neigh('the'))
# Out:
# ['inaudible', 'unwinding', 'description', 'clue', 'indeterminable']

# %%
# Sprawdzę czy zostały usuniete różne formy poszczegółnych słow spodziewam się że tak dla tego wykonam tylko 
# kilka testów 
def test(word):
    import re
    index = [False]*8267
    for i in range(len(data.columns)):
        o =re.match(word,data.columns[i])

        if o!=None:
            index[i]=True
    return data.columns[index] 
print(test('god'))
# Słowa takie jak gods czy godly budzą wątpliwości czy hipoteza była słuszna i byc może trzeba będzie zastosować
# jakiś sposób aby połączyć je w jedno
# Out:
# Index(['godvision', 'godly', 'godenlightened', 'god', 'godliness', 'godward',
#        'gods', 'godlike'],
#       dtype='object')

# %%
# Sprawdzę jescze inne słowa 
print(test('and')) # brak 
print(test('man')) # potwierdza to co pokazuje 'god'
# Out:
# Index([], dtype='object')
# Index(['manifested', 'manifold', 'mansions', 'manifestly', 'mankind',
#        'manifestations', 'manhood', 'manner', 'manna', 'managing', 'mantram',
#        'manages', 'many', 'manycoloured', 'manifesting', 'manners', 'manacles',
#        'manifestation', 'managed', 'manifests', 'manes', 'manifest', 'man',
#        'mansion', 'manageable'],
#       dtype='object')

# %% [markdown]
# Możliwe, że pomocne przy klasteryzacji okaże się zastosowanie odległości Levenshteina i przetworzenie danych tak aby słowa 'god' 'godes' były liczone razem ale biorąc pod uwagę naturę tekstów (religine) drobne różnice mogą mieć duże znaczenie, więc na razie pozostaje to tylko hipotezą.

# %%
# W zbiorze mamy księgi podzielone na rozdziały sprawdzę różnicę w częstości słow dla poszczególnych ksiąg 
data_books = data.copy()
# Generowanie tytułów ksiąg
names = []
for i in range (len(data)):
    
    names.append(re.findall('([^_]+)',data_books.iloc[i,0])[0])
names = np.unique(names)


# index for selected book 
def index_selected_book(book):
    index = [False] * 590
    for i in range(len(data)):
        
        if book == re.findall('([^_]+)',data_books.iloc[i,0])[0]:
            index[i] = True 
    index_number = [ ]
    j = 0 
    for i in index:
        if i:
            index_number.append(j)
        j+=1 
    return index_number

# Generowanie ramki z informacjami
def information_most_frequent(data,names):
    
    result = []
    
    for i in names:
        w = most_frequent_words(data.iloc[index_selected_book(i),:])
        result.append([i,w])
    
    return result

# %%
information_most_frequent(data,names)
# Out:
# [['BookOfEccleasiasticus',
#   {'shall': 508,
#    'thy': 330,
#    'man': 232,
#    'thou': 230,
#    'god': 193,
#    'hath': 189,
#    'thee': 170,
#    'lord': 152,
#    'things': 120,
#    'upon': 115}],
#  ['BookOfEcclesiastes',
#   {'shall': 89,
#    'man': 71,
#    'hath': 46,
#    'things': 46,
#    'god': 46,
#    'thy': 43,
#    'time': 42,
#    'sun': 36,
#    'also': 31,
#    'vanity': 29}],
#  ['BookOfProverb',
#   {'shall': 389,
#    'man': 176,
#    'thy': 165,
#    'thou': 93,
#    'wicked': 92,
#    'lord': 85,
#    'wise': 71,
#    'hath': 65,
#    'heart': 64,
#    'thee': 59}],
#  ['BookOfWisdom',
#   {'shall': 120,
#    'things': 89,
#    'thy': 86,
#    'god': 67,
#    'thou': 61,
#    'wisdom': 38,
#    'man': 38,
#    'upon': 37,
#    'made': 35,
#    'hath': 32}],
#  ['Buddhism',
#   {'right': 128,
#    'feeling': 85,
#    'one': 75,
#    'stress': 74,
#    'body': 73,
#    'monk': 72,
#    'mind': 71,
#    'remains': 63,
#    'cessation': 62,
#    'called': 62}],
#  ['TaoTeChing',
#   {'tao': 84,
#    'things': 56,
#    'one': 51,
#    'men': 45,
#    'great': 42,
#    'therefore': 40,
#    'heaven': 38,
#    'would': 36,
#    'thus': 33,
#    'people': 32}],
#  ['Upanishad',
#   {'one': 100,
#    'self': 79,
#    'mind': 71,
#    'brahman': 68,
#    'man': 63,
#    'death': 56,
#    'knowledge': 51,
#    'know': 50,
#    'must': 46,
#    'nachiketas': 43}],
#  ['YogaSutra',
#   {'spiritual': 300,
#    'man': 239,
#    'life': 148,
#    'consciousness': 122,
#    'power': 112,
#    'one': 108,
#    'mind': 98,
#    'soul': 94,
#    'things': 88,
#    'self': 81}]]

# %% [markdown]
# Widać wyrażne różnice po między różnymi tekstami choć wydaje się że słowa takie jak 'one','man','god','shall' powtarzają się częściej niż inne, choć dla poszczególnych ksiąg wcale nie muszą występować najczęściej.

# %% [markdown]
# _W sprawie grupowania podobnych słów_
# Nie wiem, na ile to legalne, ale proponowałbym pobrać jakiś zbiór form słownikowych słów w języku angielskim. Następnie wyszukać te formy wśród naszych słów i po ich wyznaczeniu zgrupować je z ich odmianami (słowami spoza takiej bazy). Odpowiednim regeksem typu "^"+słowo, od najdłuższego takiego podstawowego słowa, żeby nie uznano odmiany _manifest_ jako pochodzącej od _man_. Nie wiem jeszcze, jak oddzielić _man_ od *many*, a jednocześnie _manifest_ od _manifestation_.
#
# Albo jeszcze inaczej...

# %%
# spis kolumn
kolumny = data.columns[1:]
COLS = kolumny.sort_values()

# grupy słów (niżej wytłumaczenie działania)
def groups(words):
    groupsL = []
    i = 0
    j = 0
    mainword = []
    while j < 8266:
        if not re.findall('^' + words[i], words[j]) == []:
            mainword.append(words[j])
            j = j + 1
        else:
            groupsL.append(mainword)
            mainword = []
            i = j
    return groupsL
groups(COLS)
# Out:
# [['FALSE'],
#  ['TRUE'],
#  ['aaron'],
#  ['abandon', 'abandoned', 'abandoning', 'abandons'],
#  ['abase', 'abasement'],
#  ['abashed'],
#  ['abasing'],
#  ['abated'],
#  ['abates'],
#  ['abateth'],
#  ['aberrant'],
#  ['abhor', 'abhorred', 'abhorreth'],
#  ['abide', 'abides', 'abideth'],
#  ['abiding', 'abidingplace'],
#  ['abilities'],
#  ['ability'],
#  ['abiron'],
#  ['able'],
#  ['abnormal'],
#  ['abode', 'abodes'],
#  ['abolish', 'abolished'],
#  ['abominable'],
#  ['abomination', 'abominations'],
#  ['abound', 'abounded', 'aboundeth'],
#  ['abraham'],
#  ['abroad'],
#  ['absence'],
#  ['absent'],
#  ['absolute', 'absolutely'],
#  ['absorbed'],
#  ['absorbing'],
#  ['absorption'],
#  ['abstain', 'abstaineth', 'abstaining', 'abstains'],
#  ['abstinence', 'abstinences'],
#  ['abstract'],
#  ['abundance'],
#  ['abundant', 'abundantly'],
#  ['abuse'],
#  ['abusive'],
#  ['abysmal'],
#  ['abyss'],
#  ['accept', 'acceptable', 'acceptance', 'accepted', 'accepts'],
#  ['accessary'],
#  ['accidental'],
#  ['accidents'],
#  ['acclimatization'],
#  ['accompanied'],
#  ['accomplish', 'accomplished', 'accomplishment'],
#  ['accord', 'accordance', 'according'],
#  ['account', 'accounts'],
#  ['accrue'],
#  ['accumulate'],
#  ['accumulation'],
#  ['accurate'],
#  ['accursed'],
#  ['accusation'],
#  ['accuse', 'accused', 'accuser'],
#  ['accusing'],
#  ['accustomed'],
#  ['accustoming'],
#  ['achieved'],
#  ['achievement', 'achievements'],
#  ['achieves'],
#  ['acknowledge', 'acknowledged'],
#  ['acknowledgment'],
#  ['acquaint', 'acquaintance'],
#  ['acquire', 'acquired', 'acquires'],
#  ['acquisition', 'acquisitions'],
#  ['acquit', 'acquitted'],
#  ['act',
#   'acting',
#   'actings',
#   'action',
#   'actions',
#   'activates',
#   'active',
#   'activities',
#   'activity',
#   'actors',
#   'acts',
#   'actual',
#   'actually',
#   'actuates'],
#  ['adam'],
#  ['adaptation'],
#  ['adapted'],
#  ['add',
#   'added',
#   'addeth',
#   'adding',
#   'addition',
#   'addressed',
#   'addressing',
#   'adds'],
#  ['adhere', 'adherents'],
#  ['adhyatman'],
#  ['aditi'],
#  ['administer'],
#  ['admirable'],
#  ['admire', 'admired', 'admireth'],
#  ['admiring'],
#  ['admit', 'admittance'],
#  ['admonish', 'admonishest'],
#  ['adopt', 'adopted'],
#  ['adorable'],
#  ['adoration'],
#  ['adore', 'adoreth'],
#  ['adorned'],
#  ['adorneth'],
#  ['adulterer', 'adulterers'],
#  ['adulteress'],
#  ['adulterous'],
#  ['adultery'],
#  ['advance', 'advanced', 'advancement'],
#  ['advancing'],
#  ['advantage', 'advantageous'],
#  ['adversaries'],
#  ['adversary'],
#  ['adversity'],
#  ['advice'],
#  ['advise', 'advised'],
#  ['afar'],
#  ['affable'],
#  ['affair', 'affairs'],
#  ['affect', 'affected', 'affection'],
#  ['affirmations'],
#  ['affirming'],
#  ['afflict', 'afflicted', 'afflicteth', 'affliction', 'afflictions'],
#  ['afford', 'afforded'],
#  ['affrighted'],
#  ['afraid'],
#  ['afterward', 'afterwards'],
#  ['age', 'aged', 'agelong', 'agency', 'agent', 'ages'],
#  ['aggregate', 'aggregates'],
#  ['aging', 'agingaging'],
#  ['agitated'],
#  ['agni'],
#  ['ago'],
#  ['agree', 'agreeable', 'agreement', 'agrees'],
#  ['agur'],
#  ['aids'],
#  ['aim', 'aimed'],
#  ['air', 'airgod'],
#  ['akin'],
#  ['akshara'],
#  ['al',
#   'alchemy',
#   'alert',
#   'alertness',
#   'algebra',
#   'alien',
#   'alienation',
#   'alight',
#   'alike',
#   'alive',
#   'alkaline',
#   'all',
#   'allay',
#   'allcomprehending',
#   'allconscious',
#   'allconsciousness',
#   'alleging',
#   'allembracing',
#   'allencircling',
#   'allied',
#   'allimportant',
#   'allknowing',
#   'allow',
#   'allowed',
#   'allowing',
#   'allows',
#   'allpervading',
#   'allpower',
#   'allpowerful',
#   'allseeing',
#   'alluded',
#   'allurements',
#   'allureth',
#   'allwisdom',
#   'almighty',
#   'almond',
#   'almost',
#   'alms',
#   'almsgiving',
#   'aloes',
#   'alone',
#   'along',
#   'aloof',
#   'aloud',
#   'alpha',
#   'already',
#   'also',
#   'altar',
#   'altars',
#   'alter',
#   'alterations',
#   'alternates',
#   'alternation',
#   'alternative',
#   'although',
#   'alto',
#   'altogether',
#   'always'],
#  ['amalecites'],
#  ['amazed'],
#  ['ambassador'],
#  ['ambition', 'ambitions'],
#  ['amenable'],
#  ['amended'],
#  ['amendment'],
#  ['amends'],
#  ['amiable'],
#  ['amid'],
#  ['amiss'],
#  ['among', 'amongst'],
#  ['amount'],
#  ['amplification'],
#  ['amplifies'],
#  ['analogies'],
#  ['analogous'],
#  ['analyses'],
#  ['analysis'],
#  ['analytic'],
#  ['analyze'],
#  ['analyzing'],
#  ['ananda'],
#  ['ancestor'],
#  ['ancient', 'ancients'],
#  ['angel', 'angelic', 'angels'],
#  ['anger', 'angered', 'angereth'],
#  ['angles'],
#  ['angry'],
#  ['anguish'],
#  ['animal', 'animals'],
#  ['animosity'],
#  ['anointed', 'anointedst'],
#  ['anon'],
#  ['another'],
#  ['answer', 'answereth', 'answers'],
#  ['ant', 'anteroom', 'antetype', 'anticipates', 'antiquity', 'ants'],
#  ['anvil'],
#  ['anxiety'],
#  ['anxious', 'anxiously'],
#  ['anymore'],
#  ['anyone'],
#  ['anything'],
#  ['anytime'],
#  ['anywhere'],
#  ['apace'],
#  ['apana'],
#  ['apart', 'apartment'],
#  ['apertures'],
#  ['apostate'],
#  ['apostles'],
#  ['apothecary'],
#  ['appanage'],
#  ['apparel'],
#  ['apparent'],
#  ['apparition'],
#  ['appear',
#   'appearance',
#   'appearances',
#   'appeared',
#   'appeareth',
#   'appearing',
#   'appears'],
#  ['appease', 'appeased', 'appeaseth'],
#  ['appeasing'],
#  ['appetite'],
#  ['apple', 'apples'],
#  ['application'],
#  ['applied'],
#  ['applies'],
#  ['apply', 'applying'],
#  ['appoint', 'appointed'],
#  ['apprehend', 'apprehended'],
#  ['apprehension'],
#  ['apprentice'],
#  ['approach', 'approached', 'approacheth'],
#  ['appropriate'],
#  ['approved'],
#  ['approveth'],
#  ['apt'],
#  ['aqueduct'],
#  ['arani'],
#  ['archangels'],
#  ['archer'],
#  ['ardent', 'ardently'],
#  ['arduous'],
#  ['argument', 'argumentative', 'argumentativethought', 'arguments'],
#  ['aright'],
#  ['arise', 'arisen', 'arises'],
#  ['arising'],
#  ['aristotle'],
#  ['arithmetic'],
#  ['arm', 'armed', 'armies', 'armour', 'armpit', 'arms', 'army'],
#  ['aromas'],
#  ['aromatical'],
#  ['arose'],
#  ['around'],
#  ['arouse', 'aroused'],
#  ['arranging'],
#  ['array', 'arrayed'],
#  ['arresting'],
#  ['arrival'],
#  ['arrived'],
#  ['arrives'],
#  ['arriving'],
#  ['arrogance'],
#  ['arrogancy'],
#  ['arrogant', 'arrogantly'],
#  ['arrow', 'arrows'],
#  ['art',
#   'artful',
#   'articles',
#   'articulate',
#   'articulation',
#   'artificer',
#   'artificers',
#   'artist',
#   'artistic',
#   'artists',
#   'arts'],
#  ['aruni'],
#  ['as',
#   'ascend',
#   'ascended',
#   'ascending',
#   'ascension',
#   'ascent',
#   'ascetics',
#   'ashamed',
#   'ashes',
#   'aside',
#   'ask',
#   'asked',
#   'asketh',
#   'asking',
#   'asleep',
#   'aspect',
#   'aspects',
#   'aspirant',
#   'aspiration',
#   'aspirations',
#   'aspired',
#   'ass',
#   'assault',
#   'assaulted',
#   'assemblies',
#   'assembly',
#   'assent',
#   'assented',
#   'assert',
#   'asserting',
#   'asserts',
#   'assigned',
#   'assimilating',
#   'assist',
#   'associate',
#   'associated',
#   'association',
#   'associations',
#   'assuage',
#   'assumes',
#   'assumption',
#   'assurance',
#   'assured',
#   'assuredly',
#   'assures',
#   'assyrians',
#   'astonished',
#   'astonishment',
#   'astray',
#   'astronomer',
#   'astronomers',
#   'astronomy',
#   'asunder',
#   'asuras',
#   'aswattha'],
#  ['at',
#   'atma',
#   'atmagnana',
#   'atman',
#   'atmosphere',
#   'atom',
#   'atomic',
#   'atoms',
#   'atone',
#   'attached',
#   'attaches',
#   'attachment',
#   'attacking',
#   'attain',
#   'attained',
#   'attaining',
#   'attainment',
#   'attains',
#   'attemper',
#   'attempt',
#   'attempts',
#   'attend',
#   'attendant',
#   'attended',
#   'attending',
#   'attention',
#   'attenuated',
#   'attire',
#   'attitude',
#   'attract',
#   'attracts',
#   'attribute',
#   'attributed',
#   'attributes',
#   'attributeth',
#   'attribution'],
#  ['auddalaki'],
#  ['audible'],
#  ['auditory'],
#  ['august'],
#  ['aum'],
#  ['austerities'],
#  ['author', 'authoritative', 'authority'],
#  ['autumns'],
#  ['avail', 'availeth'],
#  ['avarice'],
#  ['aversion'],
#  ['avidya'],
#  ['avoid', 'avoidance', 'avoided', 'avoiding'],
#  ['avowedly'],
#  ['avyaktam'],
#  ['awake',
#   'awaked',
#   'awaken',
#   'awakened',
#   'awakening',
#   'awakes',
#   'awakest',
#   'awaketh'],
#  ['aware', 'awareness'],
#  ['away'],
#  ['awe'],
#  ['axe'],
#  ['axioms'],
#  ['axis'],
#  ['axle', 'axletree'],
#  ['aye'],
#  ['babbler'],
#  ['babbling'],
#  ['babe', 'babes'],
#  ['back', 'backbiteth', 'backbiting', 'background', 'backward'],
#  ['bad', 'badly'],
#  ['bag', 'baggage'],
#  ['balance', 'balanced'],
#  ['ball'],
#  ['balm'],
#  ['band', 'bandaging', 'bands'],
#  ['baneful'],
#  ['bank'],
#  ['banquet', 'banquets'],
#  ['banyan'],
#  ['bare', 'bared'],
#  ['baring'],
#  ['bark'],
#  ['barley'],
#  ['barns'],
#  ['barren'],
#  ['barrier', 'barriers'],
#  ['bars'],
#  ['base', 'baseballs', 'based', 'bases'],
#  ['bashfulness'],
#  ['basilisk'],
#  ['basin'],
#  ['basis'],
#  ['bastard'],
#  ['bath', 'bathman'],
#  ['battle'],
#  ['beam', 'beams'],
#  ['beans'],
#  ['beantiful'],
#  ['bear', 'beareth', 'bearing', 'bearings', 'bears'],
#  ['beast', 'beasts'],
#  ['beat', 'beaten', 'beating', 'beats'],
#  ['beauties'],
#  ['beautified'],
#  ['beautiful', 'beautifully', 'beautifulness'],
#  ['beauty'],
#  ['became'],
#  ['become', 'becomes', 'becometh'],
#  ['becoming', 'becomingbecoming', 'becomings'],
#  ['bed', 'bedding', 'beds'],
#  ['bee'],
#  ['befall', 'befallen'],
#  ['beforehand'],
#  ['beg',
#   'began',
#   'beget',
#   'beggarly',
#   'beggary',
#   'begged',
#   'begging',
#   'begin',
#   'beginneth',
#   'beginning',
#   'beginningless',
#   'beginnings',
#   'begins',
#   'begot',
#   'begotten',
#   'beguile',
#   'begun'],
#  ['behaviour'],
#  ['beheld'],
#  ['behest'],
#  ['behind'],
#  ['behold', 'beholder', 'beholdeth', 'beholding', 'beholds'],
#  ['beings'],
#  ['belief'],
#  ['belieth'],
#  ['believe', 'believed', 'believes', 'believeth'],
#  ['bellies'],
#  ['bellows'],
#  ['bells'],
#  ['belly', 'bellys'],
#  ['belong', 'belonged', 'belonging', 'belongs'],
#  ['beloved'],
#  ['bend', 'bending', 'bends'],
#  ['beneath'],
#  ['beneficent'],
#  ['beneficial'],
#  ['benefit', 'benefited', 'benefiting'],
#  ['benevolence'],
#  ['benevolent'],
#  ['benighted'],
#  ['benign'],
#  ['bent'],
#  ['beseech'],
#  ['beset'],
#  ['beside', 'besides'],
#  ['besought'],
#  ['best'],
#  ['bethhoron'],
#  ['betimes'],
#  ['better'],
#  ['betweenthetwo'],
#  ['bewailed'],
#  ['beware'],
#  ['bewildered'],
#  ['bewildering'],
#  ['bewilderment'],
#  ['bewitching'],
#  ['beyond'],
#  ['bias'],
#  ['bible', 'bibles'],
#  ['bidding'],
#  ['bile'],
#  ['bind', 'binder', 'bindeth', 'binding', 'bindinglife', 'bindings'],
#  ['binomial'],
#  ['bird', 'birds'],
#  ['birth', 'birthbirth', 'birthless', 'births'],
#  ['bite'],
#  ['biting', 'bitings'],
#  ['bitter', 'bitterest', 'bitterly', 'bitterness'],
#  ['bjorklund'],
#  ['black'],
#  ['blade'],
#  ['blame', 'blamed', 'blameless'],
#  ['blasphemies'],
#  ['blast'],
#  ['blatant'],
#  ['blaze'],
#  ['bleed'],
#  ['blemish'],
#  ['blend', 'blending', 'blends'],
#  ['bless', 'blessed', 'blesseth', 'blessing', 'blessings'],
#  ['blight'],
#  ['blind', 'blinded', 'blindeth', 'blinding', 'blindly', 'blindness'],
#  ['bliss', 'blissful'],
#  ['bloated'],
#  ['blood', 'bloodshed', 'bloodthirsty'],
#  ['bloom'],
#  ['blossomed'],
#  ['blossoms'],
#  ['blot', 'blotted'],
#  ['blow', 'bloweth', 'blown'],
#  ['blue', 'blueness'],
#  ['blunt'],
#  ['blurred'],
#  ['boards'],
#  ['boast', 'boasters', 'boasteth', 'boastful', 'boasting'],
#  ['boats'],
#  ['bodies'],
#  ['bodiless'],
#  ['bodily'],
#  ['body', 'bodyconsciousness', 'bodycontact', 'bodysphere'],
#  ['boiling'],
#  ['bold', 'boldness'],
#  ['bolts'],
#  ['bond', 'bondage', 'bondages', 'bonds', 'bondwoman'],
#  ['bone', 'bones'],
#  ['book', 'books'],
#  ['boon', 'boons'],
#  ['border', 'borderer', 'borders'],
#  ['bore'],
#  ['born', 'borne'],
#  ['borrower'],
#  ['borroweth'],
#  ['borrowing'],
#  ['bosom'],
#  ['boston'],
#  ['bottom'],
#  ['bought'],
#  ['bound', 'boundaries', 'boundary', 'bounded', 'boundless', 'bounds'],
#  ['bountiful'],
#  ['bow', 'bowed', 'bowels', 'boweth', 'bowl'],
#  ['boy'],
#  ['bracelet'],
#  ['brachiis'],
#  ['brahma', 'brahmacharya', 'brahman', 'brahmana', 'brahmans'],
#  ['brain'],
#  ['branch', 'branches'],
#  ['brass'],
#  ['brawling'],
#  ['bray'],
#  ['brazen'],
#  ['bread', 'breadth'],
#  ['break', 'breaketh', 'breaking', 'breaks'],
#  ['breast', 'breastplate', 'breasts'],
#  ['breath', 'breathe', 'breathed', 'breathes', 'breathing', 'breaths'],
#  ['breeches'],
#  ['breed', 'breeds'],
#  ['brethren'],
#  ['briars'],
#  ['bribery'],
#  ['bribes'],
#  ['bricks'],
#  ['bridge'],
#  ['bridle'],
#  ['briefly'],
#  ['bright', 'brightened', 'brighter', 'brightest', 'brightness'],
#  ['brilliant'],
#  ['brimful'],
#  ['bring', 'bringest', 'bringeth', 'bringing', 'brings'],
#  ['brink'],
#  ['brittle'],
#  ['broad'],
#  ['broke', 'broken', 'brokenness', 'brokest'],
#  ['brood', 'broods'],
#  ['brook', 'brooks'],
#  ['brother', 'brothers'],
#  ['brought', 'broughtest'],
#  ['brute'],
#  ['bubbleth'],
#  ['buckler'],
#  ['bud', 'buddha', 'buddhist', 'budding', 'buds'],
#  ['buff'],
#  ['build', 'buildeth', 'building', 'buildings', 'builds'],
#  ['built'],
#  ['bulk'],
#  ['bull', 'bulls'],
#  ['bulwarks'],
#  ['burden'],
#  ['burial'],
#  ['buried'],
#  ['burn', 'burned', 'burneth', 'burning', 'burns', 'burnt'],
#  ['burst'],
#  ['bury'],
#  ['busies'],
#  ['business'],
#  ['butcher'],
#  ['butter', 'butterfly'],
#  ['buy', 'buyer', 'buyeth', 'buying'],
#  ['byeway'],
#  ['byways'],
#  ['byword'],
#  ['cackling'],
#  ['cades'],
#  ['cage'],
#  ['cain', 'cainibid'],
#  ['calamity'],
#  ['calculates'],
#  ['caleb'],
#  ['calf'],
#  ['call', 'called', 'calleth', 'calling', 'callings'],
#  ['calm', 'calming', 'calmly'],
#  ['calumny'],
#  ['came', 'camest'],
#  ['camps'],
#  ['cancer'],
#  ['candlestick'],
#  ['candy'],
#  ['canst'],
#  ['canticles'],
#  ['canvas'],
#  ['capable'],
#  ['capacity'],
#  ['caper'],
#  ['captain'],
#  ['carbon'],
#  ['carbuncle'],
#  ['care', 'careful', 'carefully', 'carefulness', 'cares'],
#  ['carpenter'],
#  ['carriage', 'carriages'],
#  ['carried'],
#  ['carries'],
#  ['carrieth'],
#  ['carry', 'carrying'],
#  ['cart'],
#  ['carveth'],
#  ['carving'],
#  ['case', 'cases'],
#  ['cast', 'casteth', 'casting', 'castingoff', 'casts'],
#  ['catch', 'catcheth', 'catching'],
#  ['caterpillar'],
#  ['cattle'],
#  ['caught'],
#  ['causal'],
#  ['cause', 'caused', 'causes', 'causeth'],
#  ['causing'],
#  ['caution', 'cautions'],
#  ['cautious'],
#  ['cave'],
#  ['cavity'],
#  ['cease', 'ceased', 'ceaseless', 'ceaselessly', 'ceases', 'ceaseth'],
#  ['ceasing'],
#  ['cedar'],
#  ['celebrated'],
#  ['celestial'],
#  ['celibate'],
#  ['censured'],
#  ['censurer'],
#  ['censuring'],
#  ['centre', 'centred', 'centres'],
#  ['ceremonies'],
#  ['certain', 'certainly', 'certainty'],
#  ['cessation'],
#  ['chain', 'chains'],
#  ['challenge'],
#  ['chamber', 'chambers'],
#  ['chanaanite'],
#  ['chance'],
#  ['change', 'changeable', 'changed', 'changes', 'changeth'],
#  ['changing'],
#  ['channel', 'channels'],
#  ['chanted'],
#  ['chaos'],
#  ['chapte', 'chapter'],
#  ['character', 'characteristic', 'characteristics', 'characters'],
#  ['charge', 'charges'],
#  ['charging'],
#  ['chariot', 'chariots'],
#  ['charity'],
#  ['charm', 'charms'],
#  ['charnel'],
#  ['chart'],
#  ['chased'],
#  ['chaseth'],
#  ['chaste', 'chasten'],
#  ['chastise', 'chastised', 'chastisement', 'chastisest', 'chastiseth'],
#  ['chastising'],
#  ['chatter'],
#  ['check', 'checked', 'checks'],
#  ['cheek'],
#  ['cheer', 'cheereth', 'cheerful', 'cheerfully', 'cheerfulness'],
#  ['cherish', 'cherished'],
#  ['cherubims'],
#  ['chest'],
#  ['chewing'],
#  ['chief', 'chiefest', 'chiefly'],
#  ['child', 'childhood', 'childish', 'childishness', 'children'],
#  ['chimney'],
#  ['chips'],
#  ['choice'],
#  ['choke'],
#  ['choler'],
#  ['choose', 'chooser', 'chooses', 'chooseth'],
#  ['chose', 'chosen'],
#  ['christ', 'christian'],
#  ['chrysalis'],
#  ['church', 'churches'],
#  ['churlishness'],
#  ['cinnamon'],
#  ['circle'],
#  ['circuit', 'circuits'],
#  ['circumspection'],
#  ['circumstances'],
#  ['circumvented'],
#  ['cistern'],
#  ['cities'],
#  ['citizens'],
#  ['city'],
#  ['claim', 'claiming', 'claims'],
#  ['clamorous'],
#  ['clamours'],
#  ['clan', 'clans'],
#  ['clap'],
#  ['class', 'classed', 'classes', 'classified', 'classify'],
#  ['claws'],
#  ['clay'],
#  ['clean', 'cleanly', 'cleanness', 'cleanse', 'cleansed', 'cleansing'],
#  ['clear', 'cleareth', 'cleareyed', 'clearly'],
#  ['cleave', 'cleaves'],
#  ['clemency'],
#  ['climb', 'climbed', 'climbing'],
#  ['cling',
#   'clingable',
#   'clinging',
#   'clingingaggregate',
#   'clingingaggregates',
#   'clingingclingingsustenance',
#   'clingings',
#   'clingingsustenance',
#   'clings'],
#  ['clip'],
#  ['cloak'],
#  ['clods'],
#  ['cloisters'],
#  ['close', 'closed', 'closely', 'closeness', 'closer'],
#  ['closing'],
#  ['cloth', 'clothe', 'clothed', 'clothes', 'clothing'],
#  ['cloud', 'clouds'],
#  ['club'],
#  ['clue'],
#  ['clumsy'],
#  ['cluster'],
#  ['coalesce'],
#  ['coals'],
#  ['coarising'],
#  ['coarse', 'coarselooking'],
#  ['coasts'],
#  ['coat', 'coats'],
#  ['cock'],
#  ['cognize', 'cognizes'],
#  ['coins'],
#  ['cold'],
#  ['colleagues'],
#  ['collectively'],
#  ['colony'],
#  ['color'],
#  ['colour', 'coloured', 'colouring', 'colours'],
#  ['colt'],
#  ['columba'],
#  ['combative'],
#  ['combination'],
#  ['come', 'comely', 'comes', 'comest', 'comet', 'cometh'],
#  ['comfort', 'comforted', 'comforter', 'comforting'],
#  ['coming', 'comingforth', 'comingtobe'],
#  ['command',
#   'commanded',
#   'commander',
#   'commanding',
#   'commandment',
#   'commandments'],
#  ['commence', 'commenced', 'commencement'],
#  ['commend', 'commendable', 'commended'],
#  ['comment', 'commentaries', 'commentary', 'commentator', 'commentators'],
#  ['commit', 'committed'],
#  ['common', 'commonly'],
#  ['communicate', 'communicateth'],
#  ['communication'],
#  ['communing'],
#  ['communion'],
#  ['community'],
#  ['compacted'],
#  ['companion', 'companions', 'companionship'],
#  ['company'],
#  ['compare', 'compared'],
#  ['comparing'],
#  ['comparison'],
#  ['compass',
#   'compassed',
#   'compasseth',
#   'compassing',
#   'compassion',
#   'compassionate'],
#  ['compelled'],
#  ['competition'],
#  ['complain', 'complaint'],
#  ['complete', 'completed', 'completely', 'completes'],
#  ['completion'],
#  ['compliance'],
#  ['complications'],
#  ['composed'],
#  ['composition'],
#  ['composure'],
#  ['compounded'],
#  ['comprehend', 'comprehended', 'comprehending'],
#  ['comprehension'],
#  ['compulsion'],
#  ['con',
#   'conceal',
#   'concealed',
#   'concealeth',
#   'conceals',
#   'conceit',
#   'conceited',
#   'conceive',
#   'conceived',
#   'concentrated',
#   'concentration',
#   'conception',
#   'concepts',
#   'concern',
#   'concerned',
#   'concerning',
#   'concerns',
#   'concert',
#   'concertation',
#   'conclude',
#   'conclusion',
#   'concomitants',
#   'concord',
#   'concrete',
#   'concupiscence',
#   'concurring',
#   'concussion',
#   'condemn',
#   'condemnation',
#   'condemned',
#   'condemneth',
#   'condemning',
#   'condescending',
#   'condition',
#   'conditioned',
#   'conditions',
#   'condoleth',
#   'conduct',
#   'conducted',
#   'confections',
#   'conference',
#   'conferring',
#   'confess',
#   'confessed',
#   'confesseth',
#   'confidence',
#   'confident',
#   'confidently',
#   'confined',
#   'confining',
#   'confirm',
#   'confirmed',
#   'confirms',
#   'conflict',
#   'conflicting',
#   'conflicts',
#   'conform',
#   'conformable',
#   'conformity',
#   'confound',
#   'confounded',
#   'confoundeth',
#   'confounds',
#   'confront',
#   'confused',
#   'confusion',
#   'congealed',
#   'congenial',
#   'congregans',
#   'congregation',
#   'conjoined',
#   'connected',
#   'connection',
#   'conquer',
#   'conquered',
#   'conqueror',
#   'conquers',
#   'conquest',
#   'conscience',
#   'conscious',
#   'consciously',
#   'consciousness',
#   'consciousnessconsciousness',
#   'consciousnesshood',
#   'consecrated',
#   'consecration',
#   'consent',
#   'consented',
#   'consequence',
#   'consequences',
#   'consequent',
#   'consider',
#   'considerable',
#   'consideration',
#   'considered',
#   'considereth',
#   'considering',
#   'considers',
#   'consist',
#   'consistent',
#   'consists',
#   'consolation',
#   'consoling',
#   'consort',
#   'conspired',
#   'constancy',
#   'constant',
#   'constantly',
#   'constitutes',
#   'constitution',
#   'constructively',
#   'consult',
#   'consume',
#   'consumed',
#   'consumeth',
#   'consuming',
#   'consummated',
#   'contact',
#   'contactcontact',
#   'contagion',
#   'contain',
#   'containeth',
#   'containing',
#   'contemneth',
#   'contemplate',
#   'contemplated',
#   'contemplates',
#   'contemplation',
#   'contemplative',
#   'contemplatives',
#   'contempt',
#   'contemptible',
#   'contend',
#   'contends',
#   'content',
#   'contented',
#   'contention',
#   'contentions',
#   'contentious',
#   'contentment',
#   'contents',
#   'contest',
#   'continence',
#   'continent',
#   'continual',
#   'continually',
#   'continuance',
#   'continue',
#   'continued',
#   'continues',
#   'continueth',
#   'continuing',
#   'continuity',
#   'continuous',
#   'contradiction',
#   'contradictions',
#   'contradictory',
#   'contradistinction',
#   'contraries',
#   'contrary',
#   'contrast',
#   'contribute',
#   'contribution',
#   'contrivances',
#   'control',
#   'controlled',
#   'controller',
#   'controls',
#   'convenient',
#   'conventionally',
#   'converge',
#   'conversant',
#   'conversation',
#   'converse',
#   'conversely',
#   'convert',
#   'converted',
#   'convey',
#   'conveyed',
#   'conveyeth',
#   'conveying',
#   'conveys',
#   'convict',
#   'conviction',
#   'convince',
#   'convinced',
#   'convinces',
#   'convincest'],
#  ['cooking'],
#  ['cool'],
#  ['coordinated'],
#  ['copied'],
#  ['copper'],
#  ['cor',
#   'cord',
#   'cordial',
#   'cords',
#   'core',
#   'corn',
#   'corner',
#   'corners',
#   'corpse',
#   'correct',
#   'corrected',
#   'correcteth',
#   'correcting',
#   'correction',
#   'correlative',
#   'correspondence',
#   'corresponds',
#   'corrupt',
#   'corrupted',
#   'corruptible',
#   'corruption'],
#  ['cosmic'],
#  ['cost', 'costly'],
#  ['could'],
#  ['counsel', 'counsellor', 'counsellors', 'counsels'],
#  ['count',
#   'counted',
#   'countenance',
#   'counteract',
#   'countercurrent',
#   'counterfeit',
#   'counterpart',
#   'counterparts',
#   'countervail',
#   'counteth',
#   'counting',
#   'countries',
#   'country',
#   'counts'],
#  ['courage', 'courageous', 'courageously'],
#  ['course', 'courses'],
#  ['court', 'courtyard'],
#  ['covenant', 'covenants'],
#  ['cover', 'covered', 'covereth', 'covering', 'covert'],
#  ['covet', 'coveted', 'coveting', 'covetous', 'covetousness'],
#  ['cow', 'coward', 'cowardice', 'cows'],
#  ['crackling'],
#  ['craft', 'craftily', 'craftsman', 'crafty'],
#  ['craving', 'cravingcraving'],
#  ['created'],
#  ['creates'],
#  ['creation', 'creations'],
#  ['creative', 'creatively'],
#  ['creator'],
#  ['creature', 'creatures'],
#  ['credit', 'creditor'],
#  ['crevice'],
#  ['crib'],
#  ['crieth'],
#  ['crimes'],
#  ['criminal'],
#  ['crimson'],
#  ['crooked'],
#  ['cross', 'crossed', 'crosses', 'crossing', 'crossroads', 'crosswise'],
#  ['crouch', 'crouching'],
#  ['crow', 'crowded', 'crown', 'crowned', 'crowning', 'crows'],
#  ['cruel'],
#  ['crush', 'crushed'],
#  ['cry', 'crying', 'crystal'],
#  ['culmination'],
#  ['cultivation'],
#  ['cups'],
#  ['cure', 'cured'],
#  ['curiosity'],
#  ['curious'],
#  ['current', 'currents'],
#  ['curse', 'cursed', 'curses', 'curseth'],
#  ['cursing'],
#  ['custom', 'customs'],
#  ['cut', 'cuts', 'cutteth', 'cutting'],
#  ['cypress'],
#  ['dagger'],
#  ['daily'],
#  ['dainties'],
#  ['dama', 'damage'],
#  ['dance', 'dancer'],
#  ['danger', 'dangerous', 'dangers'],
#  ['dare', 'dares'],
#  ['daring'],
#  ['dark', 'darkened', 'darkeneth', 'darkness', 'darksome'],
#  ['dart'],
#  ['darwin'],
#  ['dashed'],
#  ['dashes'],
#  ['dathan'],
#  ['daughter', 'daughters'],
#  ['daunt'],
#  ['david'],
#  ['dawn', 'dawning', 'dawns'],
#  ['day', 'days', 'daytime'],
#  ['dazzle'],
#  ['dazzling'],
#  ['dead', 'deadness', 'deadweight'],
#  ['deaf', 'deafness'],
#  ['deal', 'dealer', 'dealeth', 'dealings', 'dealiug', 'deals', 'dealt'],
#  ['dear', 'dearest'],
#  ['death', 'deathdeath', 'deathless', 'deathlessness', 'deaths'],
#  ['debasement'],
#  ['debate'],
#  ['debt', 'debts'],
#  ['decay', 'decaying', 'decays'],
#  ['decease'],
#  ['deceasing'],
#  ['deceit',
#   'deceitfnl',
#   'deceitful',
#   'deceitfully',
#   'deceitfulness',
#   'deceits'],
#  ['deceive', 'deceived', 'deceiveth'],
#  ['deceiving'],
#  ['decisive'],
#  ['declaration'],
#  ['declare', 'declared', 'declares', 'declareth'],
#  ['declaring'],
#  ['decline', 'declines', 'declineth'],
#  ['decomposed'],
#  ['decreaseth'],
#  ['decree'],
#  ['decrepit', 'decrepitude'],
#  ['deduction'],
#  ['deed', 'deeds'],
#  ['deem', 'deemed', 'deems'],
#  ['deep', 'deeper', 'deepest', 'deeply'],
#  ['defeat'],
#  ['defecating'],
#  ['defective'],
#  ['defence'],
#  ['defend', 'defended', 'defender', 'defending'],
#  ['defensive'],
#  ['defer', 'deferred', 'deferreth', 'deferring'],
#  ['defiance'],
#  ['deficiencies'],
#  ['deficiency'],
#  ['deficient'],
#  ['defile', 'defiled', 'defileth'],
#  ['defiling'],
#  ['definable'],
#  ['defined'],
#  ['defines'],
#  ['definite', 'definitely'],
#  ['definition'],
#  ['deflour'],
#  ['defraud', 'defrauded', 'defraudeth'],
#  ['degree', 'degrees'],
#  ['deity'],
#  ['dejected'],
#  ['delay'],
#  ['deleterious'],
#  ['deliberation'],
#  ['delicacies'],
#  ['delicate', 'delicately'],
#  ['delicious'],
#  ['delight',
#   'delighted',
#   'delighteth',
#   'delightful',
#   'delighting',
#   'delights'],
#  ['deliver', 'delivered', 'deliverest', 'delivereth'],
#  ['deluded'],
#  ['deludes'],
#  ['delusion', 'delusions'],
#  ['delusive'],
#  ['demand', 'demanding', 'demands'],
#  ['demigod', 'demigods'],
#  ['demonstrations'],
#  ['den', 'denial', 'denied', 'denoting', 'deny', 'denying'],
#  ['depart', 'departed', 'departeth', 'departing', 'departs', 'departure'],
#  ['depend', 'dependable', 'dependence', 'dependent', 'depends'],
#  ['deplorable'],
#  ['deplores'],
#  ['depraved'],
#  ['deprive', 'deprived'],
#  ['depth', 'depths'],
#  ['derision'],
#  ['derived'],
#  ['descend', 'descended', 'descending', 'descends'],
#  ['descent'],
#  ['describe', 'described', 'describes'],
#  ['description'],
#  ['desert'],
#  ['deserve', 'deserved', 'deserveth'],
#  ['designate'],
#  ['designation', 'designations'],
#  ['designed'],
#  ['designing'],
#  ['designs'],
#  ['desirable'],
#  ['desire',
#   'desired',
#   'desireless',
#   'desirer',
#   'desires',
#   'desirest',
#   'desireth'],
#  ['desiring'],
#  ['desirous'],
#  ['desolate'],
#  ['despair', 'despairdespair'],
#  ['desperation'],
#  ['despise', 'despised', 'despiseth'],
#  ['despising'],
#  ['despoil'],
#  ['despondency'],
#  ['destination'],
#  ['destined'],
#  ['destitute'],
#  ['destroy',
#   'destroyed',
#   'destroyedst',
#   'destroyer',
#   'destroyeth',
#   'destroying',
#   'destroys'],
#  ['destructible'],
#  ['destruction'],
#  ['destructive'],
#  ['detach', 'detached', 'detachment'],
#  ['detail', 'detailed', 'details'],
#  ['detained'],
#  ['determinative'],
#  ['determine', 'determined', 'determineth'],
#  ['detestable'],
#  ['detesteth'],
#  ['dethrones'],
#  ['detract', 'detracting', 'detraction', 'detractor', 'detractors'],
#  ['deva', 'devas'],
#  ['develop',
#   'developed',
#   'developing',
#   'development',
#   'developments',
#   'develops'],
#  ['device', 'devices'],
#  ['devil'],
#  ['devise', 'devised', 'deviseth'],
#  ['devising'],
#  ['devoid'],
#  ['devoted'],
#  ['devotees'],
#  ['devotes'],
#  ['devotion'],
#  ['devour', 'devoured', 'devourers', 'devoureth'],
#  ['dew'],
#  ['dexterity'],
#  ['dhamma', 'dhammadinna'],
#  ['dharana'],
#  ['dhp'],
#  ['dhyana'],
#  ['diadem'],
#  ['dialectic'],
#  ['diamond'],
#  ['didst'],
#  ['die', 'died', 'dies', 'dieth'],
#  ['differ',
#   'difference',
#   'different',
#   'differentiate',
#   'differentiated',
#   'differentiating',
#   'differeth',
#   'differing'],
#  ['difficult', 'difficulties', 'difficulty'],
#  ['dig', 'digested', 'digged', 'diggeth', 'dignity'],
#  ['diligence'],
#  ['diligent', 'diligently'],
#  ['dimension'],
#  ['diminish', 'diminished', 'diminishes', 'diminishing'],
#  ['din'],
#  ['direct',
#   'directed',
#   'directing',
#   'direction',
#   'directions',
#   'directly',
#   'director',
#   'directs'],
#  ['direful'],
#  ['dirty'],
#  ['disadvantages'],
#  ['disappear', 'disappearance', 'disappeared'],
#  ['disappoint', 'disappointment'],
#  ['disaster'],
#  ['discard'],
#  ['discern',
#   'discerned',
#   'discernibility',
#   'discerning',
#   'discernment',
#   'discerns'],
#  ['disciple', 'disciples'],
#  ['discipline'],
#  ['disclose', 'disclosed', 'discloseth'],
#  ['disclosing'],
#  ['discomfort'],
#  ['discontented'],
#  ['discord', 'discords'],
#  ['discourse'],
#  ['discover', 'discovered', 'discovereth', 'discoveries', 'discovery'],
#  ['discreet'],
#  ['discrepancy'],
#  ['discriminate', 'discriminates'],
#  ['discriminating'],
#  ['discrimination'],
#  ['discriminative'],
#  ['discussed'],
#  ['disease'],
#  ['disenchanted'],
#  ['disenchantment'],
#  ['disentangle', 'disentangled'],
#  ['disgrace', 'disgraced'],
#  ['disguise', 'disguises'],
#  ['disgusted'],
#  ['dishonest'],
#  ['dishonour', 'dishonoured', 'dishonoureth'],
#  ['disintegrate'],
#  ['disinterested'],
#  ['disjoined'],
#  ['disjointed'],
#  ['disk'],
#  ['dislike'],
#  ['disobedience'],
#  ['disorder', 'disorderly'],
#  ['dispassion'],
#  ['dispense', 'dispensed', 'dispenser'],
#  ['disperse', 'dispersed'],
#  ['displaces'],
#  ['display', 'displayed', 'displays'],
#  ['displease', 'displeaseth'],
#  ['disposed'],
#  ['disposest'],
#  ['disposeth'],
#  ['disposition', 'dispositions'],
#  ['disputatious'],
#  ['dispute', 'disputes'],
#  ['disputing'],
#  ['disquiet', 'disquieted', 'disquieting'],
#  ['disregard', 'disregarded'],
#  ['dissemble', 'dissembler', 'dissembleth'],
#  ['dissembling'],
#  ['dissimulation'],
#  ['dissipate', 'dissipated'],
#  ['dissolution'],
#  ['dissolved'],
#  ['dissonant'],
#  ['distance', 'distances'],
#  ['distantly'],
#  ['distinct',
#   'distinction',
#   'distinctions',
#   'distinctive',
#   'distinctively',
#   'distinctly'],
#  ['distinguish',
#   'distinguishable',
#   'distinguished',
#   'distinguishes',
#   'distinguishing'],
#  ['distorted'],
#  ['distortion', 'distortions'],
#  ['distract', 'distracted', 'distraction', 'distractions'],
#  ['distress', 'distressdistress'],
#  ['distribute', 'distributed'],
#  ['distribution'],
#  ['distrustful'],
#  ['disturb', 'disturbance', 'disturbed'],
#  ['disunite'],
#  ['ditch'],
#  ['divers', 'diverse', 'diversified', 'diversities', 'diversity'],
#  ['divested'],
#  ['divide', 'divided'],
#  ['dividing'],
#  ['divination', 'divinations'],
#  ['divine', 'divined', 'divinely', 'diviner', 'divines'],
#  ['diving'],
#  ['divining'],
#  ['divinity'],
#  ['division'],
#  ['divisive'],
#  ['divulgeth'],
#  ['doctor'],
#  ['doctrine'],
#  ['doe', 'doer'],
#  ['dog', 'dogged', 'doggedly', 'dogs'],
#  ['doings'],
#  ['domestic', 'domestics'],
#  ['dominance'],
#  ['dominant'],
#  ['dominion', 'dominions'],
#  ['done'],
#  ['doom'],
#  ['door', 'doors'],
#  ['dormant'],
#  ['dost'],
#  ['doth'],
#  ['doting'],
#  ['double'],
#  ['doubling'],
#  ['doubt', 'doubted', 'doubts'],
#  ['down', 'downfall', 'downgoing', 'downward', 'downwardlife'],
#  ['dragon'],
#  ['drains'],
#  ['draw', 'draweth', 'drawing', 'drawn', 'draws'],
#  ['dread', 'dreadful'],
#  ['dream',
#   'dreaming',
#   'dreamland',
#   'dreamless',
#   'dreams',
#   'dreamworld',
#   'dreamy'],
#  ['dress', 'dressed', 'dressing'],
#  ...]

# %%
len(groups(COLS))
# Out:
# 2703

# %% [markdown]
# Słowa zostały uporządkowane alfabetycznie i zgrupowane w taki sposób, żeby pierwsze słowo w każdej grupie zaczynało wszystkie następne. W większości przypadków wygląda to sensownie, ale problem sprawiają przypadki typu "add/address/adds" i "man/manifest/mankind". Mam propozycje na poprawienie tego, ale problem zostawmy do przedyskutowania później.
#
# Tymczasem, o co chodzi z kolumnami TRUE i FALSE?

# %%
dtrue = data.TRUE
dtrue
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 585    1
# 586    0
# 587    0
# 588    0
# 589    0
# Name: TRUE, Length: 590, dtype: int64

# %%
dfalse = data.FALSE
dfalse
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 585    0
# 586    0
# 587    0
# 588    0
# 589    0
# Name: FALSE, Length: 590, dtype: int64

# %%
dtrue.plot(kind="hist", bins=4)

# %%
dfalse.plot(kind="hist", bins=7)

# %%
trufals = pd.concat([dtrue.reset_index(drop=True), dfalse], axis=1)
information_most_frequent(trufals, names)
# Out:
# [['BookOfEccleasiasticus', {'FALSE': 5}],
#  ['BookOfEcclesiastes', {'FALSE': 0}],
#  ['BookOfProverb', {'FALSE': 3}],
#  ['BookOfWisdom', {'FALSE': 0}],
#  ['Buddhism', {'FALSE': 2}],
#  ['TaoTeChing', {'FALSE': 1}],
#  ['Upanishad', {'FALSE': 0}],
#  ['YogaSutra', {'FALSE': 7}]]

# %% [markdown]
# Takich słów nie udało mi się znaleźć w oryginalnym tekście, w związku z czym sugeruje się ich usunięcie.
